# %% [markdown]
# ### Import Packages

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import cv2
import tensorflow as tf
import pandas as pd
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import os

# %%
import collections

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Face Detection

# %% [markdown]
# ### Prepare File

# %%
vid = "/content/drive/Shareddrives/20-2 ybigta project - 유튜브 썸네일 자동제작 프로그램/주펄 HL/0.58.00.mp4" #영상 경로 입력

# %%
people = int(input("동영상에 등장하는 주요인물의 수는 몇 명인가요? : ")) #영상 등장인물 수 입력
# Out:
# 동영상에 등장하는 주요인물의 수는 몇 명인가요? : 2

# %%
people
# Out:
# 2

# %% [markdown]
# ### Convert Video File to DataFrame

# %%
frames_raw = pd.DataFrame(columns=["frame","image"])

# %%
vidcap = cv2.VideoCapture(vid)
length = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))

count = 0
while(vidcap.isOpened()):
  ret, image = vidcap.read()
  # read()는 grab()와 retrieve() 두 함수를 한 함수로 불러옴
  # 두 함수를 동시에 불러오는 이유는 프레임이 존재하지 않을 때
  # grab() 함수를 이용하여 return false 혹은 NULL 값을 넘겨 주기 때문
  if (int(vidcap.get(1)) % 20 == 0):
    print("비디오 처리중 ...(",round(int(vidcap.get(1))/length*100),"%)")
    frames_raw = frames_raw.append({"frame": count,"image":cv2.cvtColor(image, cv2.COLOR_BGR2RGB)},ignore_index=True)  #frames_df에 프레임값과 image(RGB 순으로 변환) 추가
    count += 1
  elif ret is False:
    break
vidcap.release()
# Out:
# 비디오 처리중 ...( 1 %)
# 비디오 처리중 ...( 1 %)
# 비디오 처리중 ...( 2 %)
# 비디오 처리중 ...( 2 %)
# 비디오 처리중 ...( 3 %)
# 비디오 처리중 ...( 3 %)
# 비디오 처리중 ...( 4 %)
# 비디오 처리중 ...( 5 %)
# 비디오 처리중 ...( 5 %)
# 비디오 처리중 ...( 6 %)
# 비디오 처리중 ...( 6 %)
# 비디오 처리중 ...( 7 %)
# 비디오 처리중 ...( 7 %)
# 비디오 처리중 ...( 8 %)
# 비디오 처리중 ...( 8 %)
# 비디오 처리중 ...( 9 %)
# 비디오 처리중 ...( 10 %)
# 비디오 처리중 ...( 10 %)
# 비디오 처리중 ...( 11 %)
# 비디오 처리중 ...( 11 %)
# 비디오 처리중 ...( 12 %)
# 비디오 처리중 ...( 12 %)
# 비디오 처리중 ...( 13 %)
# 비디오 처리중 ...( 14 %)
# 비디오 처리중 ...( 14 %)
# 비디오 처리중 ...( 15 %)
# 비디오 처리중 ...( 15 %)
# 비디오 처리중 ...( 16 %)
# 비디오 처리중 ...( 16 %)
# 비디오 처리중 ...( 17 %)
# 비디오 처리중 ...( 18 %)
# 비디오 처리중 ...( 18 %)
# 비디오 처리중 ...( 19 %)
# 비디오 처리중 ...( 19 %)
# 비디오 처리중 ...( 20 %)
# 비디오 처리중 ...( 20 %)
# 비디오 처리중 ...( 21 %)
# 비디오 처리중 ...( 21 %)
# 비디오 처리중 ...( 22 %)
# 비디오 처리중 ...( 23 %)
# 비디오 처리중 ...( 23 %)
# 비디오 처리중 ...( 24 %)
# 비디오 처리중 ...( 24 %)
# 비디오 처리중 ...( 25 %)
# 비디오 처리중 ...( 71 %)
# 비디오 처리중 ...( 72 %)
# 비디오 처리중 ...( 72 %)
# 비디오 처리중 ...( 73 %)
# 비디오 처리중 ...( 73 %)
# 비디오 처리중 ...( 74 %)
# 비디오 처리중 ...( 75 %)
# 비디오 처리중 ...( 75 %)
# 비디오 처리중 ...( 76 %)
# 비디오 처리중 ...( 76 %)
# 비디오 처리중 ...( 77 %)
# 비디오 처리중 ...( 77 %)
# 비디오 처리중 ...( 78 %)
# 비디오 처리중 ...( 79 %)
# 비디오 처리중 ...( 79 %)
# 비디오 처리중 ...( 80 %)
# 비디오 처리중 ...( 80 %)
# 비디오 처리중 ...( 81 %)
# 비디오 처리중 ...( 81 %)
# 비디오 처리중 ...( 82 %)
# 비디오 처리중 ...( 82 %)
# 비디오 처리중 ...( 83 %)
# 비디오 처리중 ...( 84 %)
# 비디오 처리중 ...( 84 %)
# 비디오 처리중 ...( 85 %)
# 비디오 처리중 ...( 85 %)
# 비디오 처리중 ...( 86 %)
# 비디오 처리중 ...( 86 %)
# 비디오 처리중 ...( 87 %)
# 비디오 처리중 ...( 88 %)
# 비디오 처리중 ...( 88 %)
# 비디오 처리중 ...( 89 %)
# 비디오 처리중 ...( 89 %)
# 비디오 처리중 ...( 90 %)
# 비디오 처리중 ...( 90 %)
# 비디오 처리중 ...( 91 %)
# 비디오 처리중 ...( 91 %)
# 비디오 처리중 ...( 92 %)
# 비디오 처리중 ...( 93 %)
# 비디오 처리중 ...( 93 %)
# 비디오 처리중 ...( 94 %)
# 비디오 처리중 ...( 94 %)
# 비디오 처리중 ...( 95 %)
# 비디오 처리중 ...( 95 %)
# 비디오 처리중 ...( 96 %)
# 비디오 처리중 ...( 97 %)
# 비디오 처리중 ...( 97 %)
# 비디오 처리중 ...( 98 %)
# 비디오 처리중 ...( 98 %)
# 비디오 처리중 ...( 99 %)
# 비디오 처리중 ...( 99 %)
# 비디오 처리중 ...( 100 %)

# %%
len(frames_raw)
# Out:
# 177

# %% [markdown]
# ### Face Detection for All Frames

# %%
frames_df= frames_raw.copy()
face_cascade = cv2.CascadeClassifier("/content/drive/MyDrive/YBIGTA/20-2 정규학기/20-2 컨퍼런스/thumbnail_generator/face_detection/haarcascade_frontalface_default.xml") #haar cascade xml 파일 경로 입력

# %%
plt.imshow(frames_df.iloc[0,1])

# %%
plt.imshow(frames_df.iloc[1,1])

# %%
height, width, channel = frames_df.iloc[0,1].shape

# %%
clmn = ["image","face_check"]
size_clmn = []
for p in range(people):
  clmn.append("face_"+str(p+1))
  size_clmn.append("w_"+str(p+1))
  size_clmn.append("h_"+str(p+1))
face_df = pd.DataFrame(columns= clmn + size_clmn)

face_df
# Out:
# Empty DataFrame
# Columns: [image, face_check, face_1, face_2, w_1, h_1, w_2, h_2]
# Index: []

# %%
clmn = ["image","face_check"]
size_clmn = []
for p in range(people):
  clmn.append("face_"+str(p+1))
  size_clmn.append("w_"+str(p+1))
  size_clmn.append("h_"+str(p+1))
face_df = pd.DataFrame(columns= clmn + size_clmn)

k = 0
for idx in range(len(frames_df)): #한 프레임 당 이미지, 얼굴인식
  print("Frame Being Procecessed... : ", idx)
  frm = frames_df.iloc[idx,0]
  im = frames_df.iloc[idx,1]
  im_gray = cv2.cvtColor(im, cv2.COLOR_RGB2GRAY)
  face_im = im.copy()
  
  faces = face_cascade.detectMultiScale(im_gray, 1.3, 5) #얼굴 인식!
  
  if len(faces) == people : #face 인식 된 경우만
    new_face = {"image" : im}
    face_detected = 0

    for n_th in range(people): #사람별 이미지
        
        for (x,y,w,h) in [faces[n_th]]:
          if w!=0 and h!=0:
            x = max(round(x - w * 0.1) , 0)
            y = max(round(y - h * 0.3) , 0)
            w = round(w * 1.2)
            h = round(h * 1.4)

            new_face["w_"+str(n_th+1)] = w
            new_face["h_"+str(n_th+1)] = h
          
            cv2.rectangle(face_im,(x,y),(x+w,y+h),(255,0,0),2) # 원본 영상에 위치 표시
            roi_color = im[y:min(y+h,height), x:min(x+w,width)] # roi 
            new_face["face_" + str(n_th+1)] = roi_color
            face_detected += 1
            print("    The Number of Faces Detected :",face_detected)

    #한 프레임 다 끝나고      
    new_face["face_check"] = face_im
    
    if face_detected == people:
      k+=1
      print("** Faces have been detected correctly in ", k, " frames. **")
      face_df = face_df.append(new_face,ignore_index=True)

face_raw = face_df.copy()
# Out:
# Frame Being Procecessed... :  0
# Frame Being Procecessed... :  1
# Frame Being Procecessed... :  2
# Frame Being Procecessed... :  3
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  1  frames. **
# Frame Being Procecessed... :  4
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  2  frames. **
# Frame Being Procecessed... :  5
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  3  frames. **
# Frame Being Procecessed... :  6
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  4  frames. **
# Frame Being Procecessed... :  7
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  5  frames. **
# Frame Being Procecessed... :  8
# Frame Being Procecessed... :  9
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  6  frames. **
# Frame Being Procecessed... :  10
# Frame Being Procecessed... :  11
# Frame Being Procecessed... :  12
# Frame Being Procecessed... :  13
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  7  frames. **
# Frame Being Procecessed... :  14
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  8  frames. **
# Frame Being Procecessed... :  15
# Frame Being Procecessed... :  16
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  9  frames. **
# Frame Being Procecessed... :  17
# Frame Being Procecessed... :  18
# Frame Being Procecessed... :  19
# Frame Being Procecessed... :  20
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  10  frames. **
# Frame Being Procecessed... :  21
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  11  frames. **
# Frame Being Procecessed... :  22
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  12  frames. **
# Frame Being Procecessed... :  23
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  13  frames. **
# Frame Being Procecessed... :  24
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  14  frames. **
# Frame Being Procecessed... :  25
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  15  frames. **
# Frame Being Procecessed... :  26
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  16  frames. **
# Frame Being Procecessed... :  27
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  17  frames. **
# Frame Being Procecessed... :  28
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  18  frames. **
# Frame Being Procecessed... :  29
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  19  frames. **
# Frame Being Procecessed... :  30
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  20  frames. **
# Frame Being Procecessed... :  31
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  21  frames. **
# Frame Being Procecessed... :  32
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  22  frames. **
# Frame Being Procecessed... :  33
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  23  frames. **
# Frame Being Procecessed... :  34
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  24  frames. **
# Frame Being Procecessed... :  35
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  25  frames. **
# Frame Being Procecessed... :  36
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  26  frames. **
# Frame Being Procecessed... :  37
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  27  frames. **
# Frame Being Procecessed... :  38
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  28  frames. **
# Frame Being Procecessed... :  39
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  65  frames. **
# Frame Being Procecessed... :  116
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  66  frames. **
# Frame Being Procecessed... :  117
# Frame Being Procecessed... :  118
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  67  frames. **
# Frame Being Procecessed... :  119
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  68  frames. **
# Frame Being Procecessed... :  120
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  69  frames. **
# Frame Being Procecessed... :  121
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  70  frames. **
# Frame Being Procecessed... :  122
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  71  frames. **
# Frame Being Procecessed... :  123
# Frame Being Procecessed... :  124
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  72  frames. **
# Frame Being Procecessed... :  125
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  73  frames. **
# Frame Being Procecessed... :  126
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  74  frames. **
# Frame Being Procecessed... :  127
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  75  frames. **
# Frame Being Procecessed... :  128
# Frame Being Procecessed... :  129
# Frame Being Procecessed... :  130
# Frame Being Procecessed... :  131
# Frame Being Procecessed... :  132
# Frame Being Procecessed... :  133
# Frame Being Procecessed... :  134
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  76  frames. **
# Frame Being Procecessed... :  135
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  77  frames. **
# Frame Being Procecessed... :  136
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  78  frames. **
# Frame Being Procecessed... :  137
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  79  frames. **
# Frame Being Procecessed... :  138
# Frame Being Procecessed... :  139
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  80  frames. **
# Frame Being Procecessed... :  140
# Frame Being Procecessed... :  141
# Frame Being Procecessed... :  142
# Frame Being Procecessed... :  143
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  81  frames. **
# Frame Being Procecessed... :  144
# Frame Being Procecessed... :  145
# Frame Being Procecessed... :  146
# Frame Being Procecessed... :  147
# Frame Being Procecessed... :  148
# Frame Being Procecessed... :  149
# Frame Being Procecessed... :  150
# Frame Being Procecessed... :  151
# Frame Being Procecessed... :  152
# Frame Being Procecessed... :  153
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  82  frames. **
# Frame Being Procecessed... :  154
# Frame Being Procecessed... :  155
# Frame Being Procecessed... :  156
# Frame Being Procecessed... :  157
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  83  frames. **
# Frame Being Procecessed... :  158
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  84  frames. **
# Frame Being Procecessed... :  159
# Frame Being Procecessed... :  160
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  85  frames. **
# Frame Being Procecessed... :  161
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  86  frames. **
# Frame Being Procecessed... :  162
# Frame Being Procecessed... :  163
# Frame Being Procecessed... :  164
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  87  frames. **
# Frame Being Procecessed... :  165
# Frame Being Procecessed... :  166
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  88  frames. **
# Frame Being Procecessed... :  167
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  89  frames. **
# Frame Being Procecessed... :  168
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  90  frames. **
# Frame Being Procecessed... :  169
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  91  frames. **
# Frame Being Procecessed... :  170
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  92  frames. **
# Frame Being Procecessed... :  171
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  93  frames. **
# Frame Being Procecessed... :  172
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  94  frames. **
# Frame Being Procecessed... :  173
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  95  frames. **
# Frame Being Procecessed... :  174
#     The Number of Faces Detected : 1
#     The Number of Faces Detected : 2
# ** Faces have been detected correctly in  96  frames. **
# Frame Being Procecessed... :  175
# Frame Being Procecessed... :  176

# %%
len(face_df)
# Out:
# 96

# %%
face_df = face_raw.copy()

# %%
# drop outliers

face_df = face_raw.copy()

for i in size_clmn:
  quartile_1 = face_raw[i].quantile(0.25)
  quartile_3 = face_raw[i].quantile(0.75)
  print(quartile_1,quartile_3)
  IQR = quartile_3 - quartile_1
  print(IQR)
  search_df = face_df[(face_df[i] < (quartile_1 - 1.5 * IQR)) | (face_df[i] > (quartile_3 + 1.5 * IQR))]
  print(search_df.index)
  face_df.drop(list(search_df.index), axis=0,inplace = True)
  face_df.reset_index(drop=True, inplace=True)
# Out:
# 361.75 388.0
# 26.25
# Int64Index([44, 54, 80, 81, 82, 83, 94], dtype='int64')
# 422.5 452.0
# 29.5
# Int64Index([14], dtype='int64')
# 351.25 409.75
# 58.5
# Int64Index([46, 76, 77], dtype='int64')
# 409.25 477.75
# 68.5
# Int64Index([], dtype='int64')

# %%
len(face_df)
# Out:
# 85

# %%
plt.imshow(face_df.iloc[0,0]) #전체 이미지

# %%
plt.imshow(face_df.iloc[0,1]) #얼굴영역 표시 이미지

# %%
plt.imshow(face_df.iloc[0,2]) #첫번째 사람 얼굴

# %%
plt.imshow(face_df.iloc[0,3]) #두번째 사람 얼굴

# %% [markdown]
# #Emotion Classifier

# %%
emotion_classifier = load_model('/content/drive/MyDrive/YBIGTA/20-2 정규학기/20-2 컨퍼런스/thumbnail_generator/face_detection/emotion_model.hdf5', compile=False)
EMOTIONS = ["Angry" ,"Disgusting","Fearful", "Happy", "Sad", "Surpring","Neutral"]

# %%
avg_list = []
drop_list = []
for i in range(len(face_df)):
  emotion_n=0
  emotion_prob = 0
  emotion_lst = []
  labels = []
  for j in range(people):
    canvas = np.zeros((250, 300, 3), dtype="uint8")
    image = face_df.iloc[i,j+2]
    roi_gray =  cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    roi_gray = cv2.resize(roi_gray, (48, 48))
    roi_gray = roi_gray.astype("float") / 255.0
    roi_gray = img_to_array(roi_gray)
    roi_gray = np.expand_dims(roi_gray, axis=0)

    preds = emotion_classifier.predict(roi_gray)[0]
    emotion_probability = np.max(preds)
    emotion_lst.append(emotion_probability)

    if emotion_probability>0:
      emotion_n += 1
      emotion_prob += emotion_probability
      labels.append(EMOTIONS[preds.argmax()])
  
  cnt = collections.Counter(labels)
  if (emotion_n == people) and (labels.count("Neutral") <= len(labels)/2):
    avg_list.append( (emotion_prob / emotion_n) )
    #avg_list.append(np.manx(emotion_lst))
    
  else:
    drop_list.append(i)

face_df.drop(drop_list,inplace=True)
face_df.reset_index(drop=True,inplace=True)
final_df = face_df.copy()
final_df["emotion_avg"] = avg_list

# %%
len(final_df)
# Out:
# 60

# %%
drop_list
# Out:
# []

# %%
final_df.sort_values(by= "emotion_avg", inplace = True,ascending=False,ignore_index=True)

# %%
plt.imshow(final_df.iloc[0,1])

# %%
plt.imshow(final_df.iloc[1,1])

# %%
plt.imshow(final_df.iloc[2,1])

# %%
plt.imshow(final_df.iloc[3,1])

# %%
image_list = list(final_df.iloc[:,0]) #썸네일용 전체화면 이미지 리스트 (감정 높은 순)

# %%
image_list[:5]
# Out:
# [array([[[139, 155, 153],
#          [139, 155, 153],
#          [139, 155, 153],
#          ...,
#          [ 71,  84, 155],
#          [ 70,  83, 154],
#          [ 70,  83, 154]],
#
#         [[139, 155, 153],
#          [139, 155, 153],
#          [139, 155, 153],
#          ...,
#          [ 71,  84, 155],
#          [ 70,  83, 154],
#          [ 70,  83, 154]],
#
#         [[139, 155, 153],
#          [139, 155, 153],
#          [139, 155, 153],
#          ...,
#          [ 68,  80, 154],
#          [ 69,  81, 155],
#          [ 69,  81, 155]],
#
#         ...,
#
#         [[ 66,  45,  45],
#          [ 66,  45,  45],
#          [ 65,  44,  44],
#          ...,
#          [ 48,  54,  57],
#          [ 48,  54,  57],
#          [ 48,  54,  57]],
#
#         [[ 66,  45,  45],
#          [ 66,  45,  45],
#          [ 66,  45,  45],
#          ...,
#          [ 48,  54,  57],
#          [ 48,  54,  57],
#          [ 48,  54,  57]],
#
#         [[ 66,  45,  45],
#          [ 66,  45,  45],
#          [ 66,  45,  45],
#          ...,
#          [ 48,  54,  57],
#          [ 48,  54,  57],
#          [ 48,  54,  57]]], dtype=uint8), array([[[140, 157, 152],
#          [140, 157, 152],
#          [140, 157, 152],
#          ...,
#          [ 75,  79, 160],
#          [ 76,  80, 161],
#          [ 76,  80, 161]],
#
#         [[140, 157, 152],
#          [140, 157, 152],
#          [140, 157, 152],
#          ...,
#          [ 75,  79, 160],
#          [ 76,  80, 161],
#          [ 76,  80, 161]],
#
#         [[140, 157, 152],
#          [140, 157, 152],
#          [140, 157, 152],
#          ...,
#          [ 74,  79, 155],
#          [ 75,  80, 156],
#          [ 75,  80, 156]],
#
#         ...,
#
#         [[ 67,  49,  46],
#          [ 67,  49,  46],
#          [ 67,  49,  46],
#          ...,
#          [ 48,  54,  55],
#          [ 48,  54,  55],
#          [ 48,  54,  55]],
#
#         [[ 67,  49,  46],
#          [ 67,  49,  46],
#          [ 67,  49,  46],
#          ...,
#          [ 48,  54,  55],
#          [ 48,  54,  55],
#          [ 48,  54,  55]],
#
#         [[ 67,  49,  46],
#          [ 67,  49,  46],
#          [ 67,  49,  46],
#          ...,
#          [ 48,  54,  55],
#          [ 48,  54,  55],
#          [ 48,  54,  55]]], dtype=uint8), array([[[143, 157, 153],
#          [143, 157, 153],
#          [143, 157, 153],
#          ...,
#          [ 80,  77, 164],
#          [ 81,  78, 165],
#          [ 81,  78, 165]],
#
#         [[143, 157, 153],
#          [143, 157, 153],
#          [143, 157, 153],
#          ...,
#          [ 80,  77, 164],
#          [ 80,  77, 164],
#          [ 81,  78, 165]],
#
#         [[143, 157, 153],
#          [143, 157, 153],
#          [143, 157, 153],
#          ...,
#          [ 74,  76, 158],
#          [ 74,  76, 158],
#          [ 75,  77, 159]],
#
#         ...,
#
#         [[ 61,  40,  36],
#          [ 61,  40,  36],
#          [ 61,  40,  36],
#          ...,
#          [ 47,  53,  56],
#          [ 47,  53,  56],
#          [ 47,  53,  56]],
#
#         [[ 61,  40,  36],
#          [ 61,  40,  36],
#          [ 61,  40,  36],
#          ...,
#          [ 47,  53,  56],
#          [ 47,  53,  56],
#          [ 47,  53,  56]],
#
#         [[ 61,  40,  36],
#          [ 61,  40,  36],
#          [ 61,  40,  36],
#          ...,
#          [ 47,  53,  56],
#          [ 47,  53,  56],
#          [ 47,  53,  56]]], dtype=uint8), array([[[138, 155, 147],
#          [138, 155, 147],
#          [139, 156, 148],
#          ...,
#          [ 84,  79, 167],
#          [ 84,  79, 167],
#          [ 84,  79, 167]],
#
#         [[138, 155, 147],
#          [138, 155, 147],
#          [139, 156, 148],
#          ...,
#          [ 81,  76, 164],
#          [ 81,  76, 164],
#          [ 81,  76, 164]],
#
#         [[139, 156, 148],
#          [139, 156, 148],
#          [140, 157, 149],
#          ...,
#          [ 73,  76, 155],
#          [ 73,  76, 155],
#          [ 73,  76, 155]],
#
#         ...,
#
#         [[ 67,  49,  48],
#          [ 67,  49,  48],
#          [ 67,  49,  48],
#          ...,
#          [ 48,  54,  57],
#          [ 48,  54,  57],
#          [ 48,  54,  57]],
#
#         [[ 66,  48,  47],
#          [ 66,  48,  47],
#          [ 66,  48,  47],
#          ...,
#          [ 48,  54,  57],
#          [ 48,  54,  57],
#          [ 48,  54,  57]],
#
#         [[ 66,  48,  47],
#          [ 66,  48,  47],
#          [ 66,  48,  47],
#          ...,
#          [ 48,  54,  57],
#          [ 48,  54,  57],
#          [ 48,  54,  57]]], dtype=uint8), array([[[138, 157, 151],
#          [138, 157, 151],
#          [138, 157, 151],
#          ...,
#          [ 73,  79, 168],
#          [ 73,  78, 172],
#          [ 73,  78, 172]],
#
#         [[138, 157, 151],
#          [138, 157, 151],
#          [138, 157, 151],
#          ...,
#          [ 72,  78, 167],
#          [ 73,  78, 172],
#          [ 73,  78, 172]],
#
#         [[138, 157, 151],
#          [138, 157, 151],
#          [138, 157, 151],
#          ...,
#          [ 71,  78, 160],
#          [ 71,  77, 166],
#          [ 71,  77, 166]],
#
#         ...,
#
#         [[ 71,  54,  46],
#          [ 71,  54,  46],
#          [ 72,  54,  49],
#          ...,
#          [ 48,  54,  55],
#          [ 48,  54,  55],
#          [ 48,  54,  55]],
#
#         [[ 70,  53,  45],
#          [ 71,  54,  46],
#          [ 71,  53,  48],
#          ...,
#          [ 48,  54,  55],
#          [ 48,  54,  55],
#          [ 48,  54,  55]],
#
#         [[ 70,  53,  45],
#          [ 71,  54,  46],
#          [ 71,  53,  48],
#          ...,
#          [ 48,  54,  55],
#          [ 48,  54,  55],
#          [ 48,  54,  55]]], dtype=uint8)]

# %%
save_id = "주펄"
directory = "/content/drive/MyDrive/YBIGTA/20-2 정규학기/20-2 컨퍼런스/thumbnail_generator/썸네일용 얼굴인식 결과_sample/"
a_directory = directory + str(save_id) + "/전체화면/"
b_directory = directory + str(save_id) + "/얼굴별/"

if not os.path.exists(a_directory):
  os.makedirs(a_directory)

if not os.path.exists(b_directory):
  os.makedirs(b_directory)

# %%
a_directory
# Out:
# '/content/drive/MyDrive/YBIGTA/20-2 정규학기/20-2 컨퍼런스/thumbnail_generator/썸네일용 얼굴인식 결과_sample/주펄/전체화면/'

# %%
l =[len(final_df),10]
for i in range(np.min(l)):
  try:
    cv2.imwrite(a_directory+str(i)+".jpg",cv2.cvtColor(final_df.iloc[i,0], cv2.COLOR_BGR2RGB))
  
    for j in range(people):
      try:
        cv2.imwrite(b_directory+str(i)+"_"+str(j)+".jpg",cv2.cvtColor(final_df.iloc[i,j+2], cv2.COLOR_BGR2RGB))
      except:
        print("saving error!")
  except:
    print("loading error!")
